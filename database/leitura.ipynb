# %%
import pandas as pd

# %%
def faixa_etaria(fe):
    if fe['IDADE'] < 12: 
        return '0-11' 
    elif fe['IDADE']>= 12 and fe['IDADE'] <18:
         return '12-17'
    elif fe['IDADE']>= 18 and fe['IDADE'] <30:
         return '18-29'
    elif fe['IDADE']>= 30 and fe['IDADE'] <60:
         return '30-59'
    else: 
        return '>60'

# %%
rua = pd.read_csv(r'C:\Users\gusta\OneDrive\Documentos\Curso - TBD\1º Semestre\Projeto\data_set_poprua_cadunico-07-2022.csv',encoding='cp860',delimiter=';',usecols=[0,1,2,3,4,5,7,8,9,10,11,12])
rua['Faixa_etaria'] = rua.apply(faixa_etaria, axis=1)
rua
# Out:
#                TEMPO_VIVE_NA_RUA CONTATO_PARENTE_FORA_RUAS DATA_NASCIMENTO  \
# 0                 Ate seis meses                     Nunca      09/05/2002
# 1                 Ate seis meses               Quase nunca      04/06/1986
# 2                 Ate seis meses               Quase nunca      02/07/1967
# 3                 Ate seis meses                  Todo mes      01/03/1992
# 4               Mais de dez anos                  Todo dia      03/04/1958
# ...                          ...                       ...             ...
# 10651  Entre seis meses e um ano                     Nunca      28/10/1969
# 10652       Entre um e dois anos               Quase nunca      07/06/2001
# 10653    Entre dois e cinco anos                     Nunca      23/12/1961
# 10654  Entre seis meses e um ano                     Nunca      11/03/1998
# 10655    Entre dois e cinco anos                  Todo mes      30/03/1986
#
#        IDADE       SEXO AUXILIO_BRASIL          GRAU_INSTRUCAO COR_RACA  \
# 0         20  MASCULINO            NAO    Fundamental completo    Parda
# 1         36  MASCULINO            NAO        Medio incompleto    Parda
# 2         55   FEMININO            NAO        Medio incompleto    Preta
# 3         30   FEMININO            NAO           Sem instrucao    Preta
# 4         64   FEMININO            NAO  Fundamental incompleto    Parda
# ...      ...        ...            ...                     ...      ...
# 10651     52  MASCULINO            SIM           Sem instrucao    Preta
# 10652     21  MASCULINO            SIM    Fundamental completo    Parda
# 10653     60  MASCULINO            SIM    Fundamental completo   Branca
# 10654     24  MASCULINO            SIM        Medio incompleto    Parda
# 10655     36   FEMININO            SIM    Fundamental completo    Parda
#
#           Faixa da renda familiar per capita  VAL_REMUNERACAO_MES_PASSADO  \
# 0      Entre R$210.01 ate 0.5 Salario Minimo                          0.0
# 1                Acima de 0.5 Salario Minimo                          0.0
# 2                               Ate R$105.00                          0.0
# 3      Entre R$210.01 ate 0.5 Salario Minimo                          0.0
# 4                Acima de 0.5 Salario Minimo                          0.0
# ...                                      ...                          ...
# 10651                           Ate R$105.00                          0.0
# 10652                           Ate R$105.00                          0.0
# 10653                           Ate R$105.00                          0.0
# 10654                           Ate R$105.00                          0.0
# 10655                           Ate R$105.00                         40.0
#
#                       CRAS    REGIONAL Faixa_etaria
# 0          CRAS VILA CEMIG    BARREIRO        18-29
# 1       TPSA Sao Gabriel I    NORDESTE        30-59
# 2              TPSA Centro  CENTRO SUL        30-59
# 3         CRAS VILA ANTENA       OESTE        30-59
# 4              TPSA Centro  CENTRO SUL          >60
# ...                    ...         ...          ...
# 10651          TPSA Centro  CENTRO SUL        30-59
# 10652          TPSA Centro  CENTRO SUL        18-29
# 10653  CRAS VILA COQUEIRAL    NOROESTE          >60
# 10654  TPSA Jardim AmΘrica       OESTE        18-29
# 10655      TPSA Dona Clara    PAMPULHA        30-59
#
# [10656 rows x 13 columns]
